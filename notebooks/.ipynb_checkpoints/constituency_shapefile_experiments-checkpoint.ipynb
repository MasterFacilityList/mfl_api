# %% [markdown]
# First, set up Django

# %%
import os
import sys

if __name__ == "__main__":
    os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")
    
import django
django.setup()
# Out:
# /home/ngurenyaga/.virtualenvs/mfl/local/lib/python2.7/site-packages/reversion/admin.py:16: RemovedInDjango19Warning: django.contrib.contenttypes.generic is deprecated and will be removed in Django 1.9. Its contents have been moved to the fields, forms, and admin submodules of django.contrib.contenttypes.
#   from django.contrib.contenttypes.generic import GenericInlineModelAdmin, GenericRelation
#
# WARNING:py.warnings:/home/ngurenyaga/.virtualenvs/mfl/local/lib/python2.7/site-packages/reversion/admin.py:16: RemovedInDjango19Warning: django.contrib.contenttypes.generic is deprecated and will be removed in Django 1.9. Its contents have been moved to the fields, forms, and admin submodules of django.contrib.contenttypes.
#   from django.contrib.contenttypes.generic import GenericInlineModelAdmin, GenericRelation
#
# /home/ngurenyaga/.virtualenvs/mfl/local/lib/python2.7/site-packages/django/contrib/sites/models.py:78: RemovedInDjango19Warning: Model class django.contrib.sites.models.Site doesn't declare an explicit app_label and either isn't in an application in INSTALLED_APPS or else was imported before its application was loaded. This will no longer be supported in Django 1.9.
#   class Site(models.Model):
#
# WARNING:py.warnings:/home/ngurenyaga/.virtualenvs/mfl/local/lib/python2.7/site-packages/django/contrib/sites/models.py:78: RemovedInDjango19Warning: Model class django.contrib.sites.models.Site doesn't declare an explicit app_label and either isn't in an application in INSTALLED_APPS or else was imported before its application was loaded. This will no longer be supported in Django 1.9.
#   class Site(models.Model):

# %% [markdown]
# Next, get a reference to the constituencies shape file

# %%
from django.conf import settings
constituencies_shp = os.path.abspath(os.path.join(settings.BASE_DIR, 'mfl_gis/data/constituencies/constituencies.shp'))

# %% [markdown]
# Now, use the LayerMapping utility to read the file into the model

# %%
from django.contrib.gis.gdal import DataSource

constituencies_datasource = DataSource(constituencies_shp)

# %%
constituencies_layer = constituencies_datasource[0]
constituencies_layer.fields
# Out:
# [u'OBJECTID',
#  u'COUNTY_NAM',
#  u'CONST_CODE',
#  u'CONSTITUEN',
#  u'COUNTY_ASS',
#  u'COUNTY_A_1',
#  u'REGIST_CEN',
#  u'REGISTRATI',
#  u'COUNTY_COD',
#  u'Shape_Leng',
#  u'Shape_Area']

# %%
constituency_details = []
for constituency in constituencies_layer:
    constituency_details.append({
        'object_id': constituency.get('OBJECTID'),
        'county': constituency.get('COUNTY_NAM'),
        'constituency_code': constituency.get('CONST_CODE'),
        'name': constituency.get('CONSTITUEN'),
        'county_code': constituency.get('COUNTY_COD')
    })

print(len(constituency_details))
# Out:
#   File "<ipython-input-8-0d7f5bab3735>", line 9
#     } if constituency.get('CONST_CODE'))
#                                        ^
# SyntaxError: invalid syntax

# %%
import json

json.dumps(constituency_details)
# Out:
# '[{"code": 47.0, "length": 0.16463159484, "constituency_code": 288.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.00097789543, "county_a_1": "", "object_id": 1}, {"code": 47.0, "length": 0.412418271, "constituency_code": 274.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.00590940422, "county_a_1": "", "object_id": 2}, {"code": 47.0, "length": 0.23240904878, "constituency_code": 275.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.00238495981, "county_a_1": "", "object_id": 3}, {"code": 47.0, "length": 0.38435691792, "constituency_code": 279.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.00390835085, "county_a_1": "", "object_id": 4}, {"code": 47.0, "length": 0.20691462512, "constituency_code": 289.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.0013252425, "county_a_1": "", "object_id": 5}, {"code": 47.0, "length": 0.85501283095, "constituency_code": 277.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.01695002792, "county_a_1": "", "object_id": 6}, {"code": 47.0, "length": 0.27504846949, "constituency_code": 276.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.00198705385, "county_a_1": "", "object_id": 7}, {"code": 47.0, "length": 0.72368735459, "constituency_code": 280.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.01106947106, "county_a_1": "", "object_id": 8}, {"code": 47.0, "length": 0.17518274743, "constituency_code": 281.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.00058465551, "county_a_1": "", "object_id": 9}, {"code": 47.0, "length": 0.20791276766, "constituency_code": 278.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.00107963649, "county_a_1": "", "object_id": 10}, {"code": 47.0, "length": 0.11037446801, "constituency_code": 290.0, "name": "NAIROBI", "county_assembly": 0.0, "area": 0.00023579934, "county_a_1": "", "object_id": 11}, {"code": 1.0, "length": 0.52664125713, "constituency_code": 3.0, "name": "MOMBASA", "county_assembly": 9.0, "area": 0.00833934322, "county_a_1": "MJAMBERE", "object_id": 12}, {"code": 1.0, "length": 0.16069602318, "constituency_code": 6.0, "name": "MOMBASA", "county_assembly": 27.0, "area": 0.00145444635, "county_a_1": "TUDOR", "object_id": 13}, {"code": 1.0, "length": 0.35435783122, "constituency_code": 2.0, "name": "MOMBASA", "county_assembly": 8.0, "area": 0.00358542502, "county_a_1": "MIKINDANI", "object_id": 14}, {"code": 1.0, "length": 0.20497240809, "constituency_code": 4.0, "name": "MOMBASA", "county_assembly": 16.0, "area": 0.00224195553, "county_a_1": "FRERE TOWN", "object_id": 15}, {"code": 1.0, "length": 0.41795551234, "constituency_code": 5.0, "name": "MOMBASA", "county_assembly": 21.0, "area": 0.00484670774, "county_a_1": "MTONGWE", "object_id": 16}, {"code": 2.0, "length": 3.86298161214, "constituency_code": 10.0, "name": "KWALE", "county_assembly": 47.0, "area": 0.39364001537, "county_a_1": "MACKINNON ROAD", "object_id": 17}, {"code": 2.0, "length": 1.86644313611, "constituency_code": 9.0, "name": "KWALE", "county_assembly": 0.0, "area": 0.09759227557, "county_a_1": "", "object_id": 18}, {"code": 2.0, "length": 2.49277229975, "constituency_code": 8.0, "name": "KWALE", "county_assembly": 0.0, "area": 0.1901631373, "county_a_1": "", "object_id": 19}, {"code": 2.0, "length": 1.2660909895, "constituency_code": 7.0, "name": "KWALE", "county_assembly": 31.0, "area": 0.07672823594, "county_a_1": "GOMBATO BONGWE", "object_id": 20}, {"code": 3.0, "length": 1.39461712732, "constituency_code": 13.0, "name": "KILIFI", "county_assembly": 63.0, "area": 0.05901884101, "county_a_1": "MARIAKANI", "object_id": 21}, {"code": 3.0, "length": 2.53314450941, "constituency_code": 15.0, "name": "KILIFI", "county_assembly": 74.0, "area": 0.23884174415, "county_a_1": "SOKOKE", "object_id": 22}, {"code": 3.0, "length": 2.47647272332, "constituency_code": 11.0, "name": "KILIFI", "county_assembly": 55.0, "area": 0.06379362004, "county_a_1": "MATSANGONI", "object_id": 23}, {"code": 3.0, "length": 1.02411262714, "const ...
